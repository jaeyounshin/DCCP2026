# %%
print("Hello, Codespace!")
print("12강 실습 시작!")
# Out:
# Hello, Codespace!
# 12강 실습 시작!

# %%
git add .
git commit -m "12강 실습"
git push
# Out:
#   Cell In[3], line 1
#     git add .
#         ^
# SyntaxError: invalid syntax
